# %%
import pandas as pd

df = pd.read_csv("ecommerce_dataset.csv", names=["category", "description"],header=None)
df.head(3)
# Out:
#     category                                        description
# 0  Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  Household  SAF 'UV Textured Modern Art Print Framed' Pain...

# %%
df.category.value_counts()
# Out:
# category
# Household                 19313
# Books                     11820
# Electronics               10621
# Clothing & Accessories     8671
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (50425, 2)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (50424, 2)

# %%
df.category.replace("Clothing & Accessories", "Clothing_Accessories", inplace=True)
df.category.unique()
# Out:
# C:\Users\malha\AppData\Local\Temp\ipykernel_40944\3168945168.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.category.replace("Clothing & Accessories", "Clothing_Accessories", inplace=True)
# array(['Household', 'Books', 'Clothing_Accessories', 'Electronics'],
#       dtype=object)

# %%
df['category'] = "__label__" + df['category'].astype(str)
df.head()
# Out:
#              category                                        description
# 0  __label__Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  __label__Household  Incredible Gifts India Wooden Happy Birthday U...

# %%
df['category_description'] = df['category'] + " " + df['description']
df.head()
# Out:
#              category                                        description  \
# 0  __label__Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  __label__Household  Incredible Gifts India Wooden Happy Birthday U...
#
#                                 category_description
# 0  __label__Household Paper Plane Design Framed W...
# 1  __label__Household SAF 'Floral' Framed Paintin...
# 2  __label__Household SAF 'UV Textured Modern Art...
# 3  __label__Household SAF Flower Print Framed Pai...
# 4  __label__Household Incredible Gifts India Wood...

# %%
import re
def preprocess(text):
    text = re.sub('[^\w\s]', ' ', text, flags=re.MULTILINE)
    text = re.sub(' +', ' ', text, flags=re.MULTILINE)
    return text.strip().lower()

# %%
preprocess("hi!, my name is .. malhar,,, will you? be my friend...")
# Out:
# 'hi my name is malhar will you be my friend'

# %%
df['category_description'] = df['category_description'].map(preprocess)

# %%
df.head()
# Out:
#              category                                        description  \
# 0  __label__Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  __label__Household  Incredible Gifts India Wooden Happy Birthday U...
#
#                                 category_description
# 0  __label__household paper plane design framed w...
# 1  __label__household saf floral framed painting ...
# 2  __label__household saf uv textured modern art ...
# 3  __label__household saf flower print framed pai...
# 4  __label__household incredible gifts india wood...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
test
# Out:
#                             category  \
# 40359           __label__Electronics
# 10647             __label__Household
# 7008              __label__Household
# 50371           __label__Electronics
# 20656                 __label__Books
# ...                              ...
# 43627           __label__Electronics
# 14730             __label__Household
# 24710                 __label__Books
# 34461  __label__Clothing_Accessories
# 11621             __label__Household
#
#                                              description  \
# 40359  Paper Plane Design 004_Army Army Collection La...
# 10647  Storite Pistole shape Metal Impulse Igniter Sp...
# 7008   Fortune Premium 10 - Pieces Stainless Steel Ba...
# 50371  Apple iPhone XR (Red, 3GB RAM, 64GB Storage, 1...
# 20656  On Directing Film Amazon.com Review According ...
# ...                                                  ...
# 43627  Samsung 27 inch (68.6 cm) Curved Bezel Less LE...
# 14730  Bajaj Majesty 1603 T 16-Litre Oven Toaster Gri...
# 24710  UGC-NET/JRF/SET Education (Paper II & III) It ...
# 34461  Sojanya (Since 1958) Men's Sky Blue Cotton Lin...
# 11621  Dynore Stainless Steel Tong Set, Set of 3, Sil...
#
#                                     category_description
# 40359  __label__electronics paper plane design 004_ar...
# 10647  __label__household storite pistole shape metal...
# 7008   __label__household fortune premium 10 pieces s...
# 50371  __label__electronics apple iphone xr red 3gb r...
# 20656  __label__books on directing film amazon com re...
# ...                                                  ...
# 43627  __label__electronics samsung 27 inch 68 6 cm c...
# 14730  __label__household bajaj majesty 1603 t 16 lit...
# 24710  __label__books ugc net jrf set education paper...
# 34461  __label__clothing_accessories sojanya since 19...
# 11621  __label__household dynore stainless steel tong...
#
# [10085 rows x 3 columns]

# %%
train.to_csv("ecommerce.train", columns=['category_description'], header=None, index=False)
test.to_csv("ecommerce.test", columns=['category_description'], header=None, index=False)

# %%
import fasttext
model = fasttext.train_supervised(input="ecommerce.train")
model.test("ecommerce.test")

# output ---> (test size, precision, recall)
# Out:
# (10082, 0.965383852410236, 0.965383852410236)

# %%
model.get_nearest_neighbors("sony")
# Out:
# [(0.9983512759208679, 'dvd'),
#  (0.9982203841209412, 'antenna'),
#  (0.9977090358734131, 'binocular'),
#  (0.9973396062850952, 'devices'),
#  (0.9967654347419739, 'whey'),
#  (0.9967459440231323, 'glossy'),
#  (0.9966604709625244, 'binoculars'),
#  (0.9966168403625488, 'viewing'),
#  (0.9965702891349792, 'charger'),
#  (0.9964793920516968, 'mac')]
