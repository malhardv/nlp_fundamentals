# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = [
    "Thor eating pizza, Loki is eating pizza, Ironman ate already",
    "Apple is announcing new iPhone tomorrow",
    "Tesla is announcing new model-3 tomorrow",
    "Google is announcing new pixel-6 tomorrow",
    "Microsoft is announcing new surface tomorrow",
    "Amazon is accouning new echo-dot tomorrow",
    "I am eating biryani and you are eating grapes",
    "something is amazing"
]

# %%
v = TfidfVectorizer()
transformed_corpus = v.fit_transform(corpus)
v.vocabulary_
# Out:
# {'thor': 28,
#  'eating': 12,
#  'pizza': 24,
#  'loki': 19,
#  'is': 18,
#  'ironman': 17,
#  'ate': 9,
#  'already': 1,
#  'apple': 7,
#  'announcing': 6,
#  'new': 22,
#  'iphone': 16,
#  'tomorrow': 29,
#  'tesla': 27,
#  'model': 21,
#  'google': 14,
#  'pixel': 23,
#  'microsoft': 20,
#  'surface': 26,
#  'amazon': 4,
#  'accouning': 0,
#  'echo': 13,
#  'dot': 11,
#  'am': 2,
#  'biryani': 10,
#  'and': 5,
#  'you': 30,
#  'are': 8,
#  'grapes': 15,
#  'something': 25,
#  'amazing': 3}

# %%
dir(v)
# Out:
# ['_CountVectorizer__metadata_request__fit',
#  '_CountVectorizer__metadata_request__transform',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_request_for_signature',
#  '_char_ngrams',
#  '_char_wb_ngrams',
#  '_check_params',
#  '_check_stop_words_consistency',
#  '_check_vocabulary',
#  '_count_vocab',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_html_repr',
#  '_limit_features',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_sort_features',
#  '_stop_words_id',
#  '_tfidf',
#  '_validate_ngram_range',
#  '_validate_params',
#  '_validate_vocabulary',
#  '_warn_for_unused_params',
#  '_white_spaces',
#  '_word_ngrams',
#  'analyzer',
#  'binary',
#  'build_analyzer',
#  'build_preprocessor',
#  'build_tokenizer',
#  'decode',
#  'decode_error',
#  'dtype',
#  'encoding',
#  'fit',
#  'fit_transform',
#  'fixed_vocabulary_',
#  'get_feature_names_out',
#  'get_metadata_routing',
#  'get_params',
#  'get_stop_words',
#  'idf_',
#  'input',
#  'inverse_transform',
#  'lowercase',
#  'max_df',
#  'max_features',
#  'min_df',
#  'ngram_range',
#  'norm',
#  'preprocessor',
#  'set_params',
#  'smooth_idf',
#  'stop_words',
#  'strip_accents',
#  'sublinear_tf',
#  'token_pattern',
#  'tokenizer',
#  'transform',
#  'use_idf',
#  'vocabulary',
#  'vocabulary_']

# %%
v.get_feature_names_out()
# Out:
# array(['accouning', 'already', 'am', 'amazing', 'amazon', 'and',
#        'announcing', 'apple', 'are', 'ate', 'biryani', 'dot', 'eating',
#        'echo', 'google', 'grapes', 'iphone', 'ironman', 'is', 'loki',
#        'microsoft', 'model', 'new', 'pixel', 'pizza', 'something',
#        'surface', 'tesla', 'thor', 'tomorrow', 'you'], dtype=object)

# %%
v.idf_
# Out:
# array([2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.58778666, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.11778304, 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.40546511, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 1.40546511,
#        2.5040774 ])

# %%
all_feature_names = v.get_feature_names_out()
for word in all_feature_names:
    idx = v.vocabulary_.get(word)
    print(f"{word} : {v.idf_[idx]}")
# Out:
# accouning : 2.504077396776274
# already : 2.504077396776274
# am : 2.504077396776274
# amazing : 2.504077396776274
# amazon : 2.504077396776274
# and : 2.504077396776274
# announcing : 1.587786664902119
# apple : 2.504077396776274
# are : 2.504077396776274
# ate : 2.504077396776274
# biryani : 2.504077396776274
# dot : 2.504077396776274
# eating : 2.09861228866811
# echo : 2.504077396776274
# google : 2.504077396776274
# grapes : 2.504077396776274
# iphone : 2.504077396776274
# ironman : 2.504077396776274
# is : 1.1177830356563834
# loki : 2.504077396776274
# microsoft : 2.504077396776274
# model : 2.504077396776274
# new : 1.4054651081081644
# pixel : 2.504077396776274
# pizza : 2.504077396776274
# something : 2.504077396776274
# surface : 2.504077396776274
# tesla : 2.504077396776274
# thor : 2.504077396776274
# tomorrow : 1.4054651081081644
# you : 2.504077396776274

# %%
corpus[:2]
# Out:
# ['Thor eating pizza, Loki is eating pizza, Ironman ate already',
#  'Apple is announcing new iPhone tomorrow']

# %%
transformed_corpus.toarray()[:2]
# Out:
# array([[0.        , 0.28856984, 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.28856984,
#         0.        , 0.        , 0.48368809, 0.        , 0.        ,
#         0.        , 0.        , 0.28856984, 0.1288133 , 0.28856984,
#         0.        , 0.        , 0.        , 0.        , 0.57713968,
#         0.        , 0.        , 0.        , 0.28856984, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.35273718, 0.55629716, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.55629716, 0.        , 0.24832281, 0.        ,
#         0.        , 0.        , 0.31223326, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.31223326,
#         0.        ]])

# %%
import pandas as pd
df = pd.read_csv("Ecommerce_data.csv")
print(df.shape)
df.head()
# Out:
# (24000, 2)
#                                                 Text                   label
# 0  Urban Ladder Eisner Low Back Study-Office Comp...               Household
# 1  Contrast living Wooden Decorative Box,Painted ...               Household
# 2  IO Crest SY-PCI40010 PCI RAID Host Controller ...             Electronics
# 3  ISAKAA Baby Socks from Just Born to 8 Years- P...  Clothing & Accessories
# 4  Indira Designer Women's Art Mysore Silk Saree ...  Clothing & Accessories

# %%
df.label.value_counts()
# Out:
# label
# Household                 6000
# Electronics               6000
# Clothing & Accessories    6000
# Books                     6000
# Name: count, dtype: int64

# %%
df['label_num'] = df.label.map({
    'Household': 0,
    'Electronics': 1,
    'Clothing & Accessories': 2,
    'Books': 3
})
df.head()
# Out:
#                                                 Text                   label  \
# 0  Urban Ladder Eisner Low Back Study-Office Comp...               Household
# 1  Contrast living Wooden Decorative Box,Painted ...               Household
# 2  IO Crest SY-PCI40010 PCI RAID Host Controller ...             Electronics
# 3  ISAKAA Baby Socks from Just Born to 8 Years- P...  Clothing & Accessories
# 4  Indira Designer Women's Art Mysore Silk Saree ...  Clothing & Accessories
#
#    label_num
# 0          0
# 1          0
# 2          1
# 3          2
# 4          2

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df.Text,
    df.label_num,
    test_size=0.2,
    random_state=2345,
    stratify=df.label_num
)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
# Out:
# Shape of X_train: (19200,)
# Shape of X_test: (4800,)

# %%
y_train.value_counts()
# Out:
# label_num
# 1    4800
# 0    4800
# 3    4800
# 2    4800
# Name: count, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer

clf = Pipeline([
    ('tfidfVectorizer', TfidfVectorizer()),
    ('Model', KNeighborsClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1200
#            1       0.97      0.98      0.97      1200
#            2       0.98      0.97      0.98      1200
#            3       0.97      0.95      0.96      1200
#
#     accuracy                           0.97      4800
#    macro avg       0.97      0.97      0.97      4800
# weighted avg       0.97      0.97      0.97      4800

# %%
y_test[:5]
# Out:
# 16694    0
# 7970     2
# 19018    3
# 2471     3
# 6190     0
# Name: label_num, dtype: int64

# %%
y_pred[:5]
# Out:
# array([0, 2, 3, 3, 0])

# %%
from sklearn.naive_bayes import MultinomialNB

clf = Pipeline([
    ('Vectorizer', TfidfVectorizer()),
    ('Model', MultinomialNB())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95      1200
#            1       0.97      0.98      0.97      1200
#            2       0.97      0.98      0.98      1200
#            3       0.98      0.93      0.96      1200
#
#     accuracy                           0.96      4800
#    macro avg       0.96      0.96      0.96      4800
# weighted avg       0.96      0.96      0.96      4800

# %%
from sklearn.ensemble import RandomForestClassifier

clf = Pipeline([
    ('Vectorizer', TfidfVectorizer()),
    ('Model', RandomForestClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1200
#            1       0.98      0.98      0.98      1200
#            2       0.98      0.98      0.98      1200
#            3       0.98      0.98      0.98      1200
#
#     accuracy                           0.98      4800
#    macro avg       0.98      0.98      0.98      4800
# weighted avg       0.98      0.98      0.98      4800

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def preprocess(text):
    doc = nlp(text)
    filtered_text = []
    
    for token in doc:
        if token.is_stop and token.is_punct:
            continue
        filtered_text.append(token.text)

    return " ".join(filtered_text)

# %%
df['filtered_text'] = df['Text'].apply(preprocess)
df.head()
# Out:
#                                                 Text                   label  \
# 0  Urban Ladder Eisner Low Back Study-Office Comp...               Household
# 1  Contrast living Wooden Decorative Box,Painted ...               Household
# 2  IO Crest SY-PCI40010 PCI RAID Host Controller ...             Electronics
# 3  ISAKAA Baby Socks from Just Born to 8 Years- P...  Clothing & Accessories
# 4  Indira Designer Women's Art Mysore Silk Saree ...  Clothing & Accessories
#
#    label_num                                      filtered_text
# 0          0  Urban Ladder Eisner Low Back Study - Office Co...
# 1          0  Contrast living Wooden Decorative Box , Painte...
# 2          1  IO Crest SY - PCI40010 PCI RAID Host Controlle...
# 3          2  ISAKAA Baby Socks from Just Born to 8 Years- P...
# 4          2  Indira Designer Women 's Art Mysore Silk Saree...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.filtered_text,
    df.label_num,
    test_size=0.2,
    random_state=2345,
    stratify=df.label_num
)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
# Out:
# Shape of X_train: (19200,)
# Shape of X_test: (4800,)

# %%
y_train.value_counts()
# Out:
# label_num
# 1    4800
# 0    4800
# 3    4800
# 2    4800
# Name: count, dtype: int64

# %%
clf = Pipeline([
    ('tfidfVectorizer', TfidfVectorizer()),
    ('Model', KNeighborsClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1200
#            1       0.97      0.98      0.97      1200
#            2       0.98      0.97      0.98      1200
#            3       0.97      0.95      0.96      1200
#
#     accuracy                           0.97      4800
#    macro avg       0.97      0.97      0.97      4800
# weighted avg       0.97      0.97      0.97      4800

# %%
clf = Pipeline([
    ('Vectorizer', TfidfVectorizer()),
    ('Model', MultinomialNB())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95      1200
#            1       0.97      0.98      0.97      1200
#            2       0.98      0.98      0.98      1200
#            3       0.98      0.93      0.96      1200
#
#     accuracy                           0.96      4800
#    macro avg       0.96      0.96      0.96      4800
# weighted avg       0.96      0.96      0.96      4800

# %%
clf = Pipeline([
    ('Vectorizer', TfidfVectorizer()),
    ('Model', RandomForestClassifier())
])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1200
#            1       0.98      0.97      0.98      1200
#            2       0.99      0.99      0.99      1200
#            3       0.98      0.98      0.98      1200
#
#     accuracy                           0.98      4800
#    macro avg       0.98      0.98      0.98      4800
# weighted avg       0.98      0.98      0.98      4800
